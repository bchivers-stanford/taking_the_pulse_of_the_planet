# %% [markdown]
# <a href="https://colab.research.google.com/github/envgp/taking_the_pulse_of_the_planet/blob/main/notebooks/pulse_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1: Taking the Pulse of the Atmosphere
#
# Seogi Kang (sgkang09@stanford.edu)& Rosemary Knight(rknight@stanford.edu), Stanford Environmental Geophysics Research Group
#
# This assignment is due on`2023-1-24`. Please put your answers within this notebook and share the completed notebook with the graders, bsalvado@stanford.edu and sgkang09@stanford.edu, using the Share banner located at the top right corner of this notebook. When sharing your notebook, please change the name of the notebook and add your name and sunetid (e.g., `pulse_course_assignment_1_firstname_lastname_sunetid.ipynb`)
#
# ## INTRODUCTION TO THE ASSIGNMENT
#
# In this assignment, we will explore the changing concentration of greenhouse gases in the atmosphere -  CO2 and CH4, which is what is driving climate change. We will also review measurement of the other trace gases NO2 and CO which are not primary drivers of climate change, but do have an impact on air quality, a concern in terms of sustainability with related environmental justice issues.
#
# ## DATA SETS
#
# Data sets used this assignment are:
# - CO2 - one time-series at one location
# - Gridded data - CO2 in space and time (time-series at many locations)
# - Gridded data - CH4 in space and time (time-series at many locations)
# - Gridded data - NO2 in space and time (time-series at many locations)
# - Gridded data - CO in space and time (time-series at many locations)
#
# ## BUILDING YOUR TOOLBOX
#
# This is the first assignment of the course, so we will use this and the next assignment to introduce core tools including Google Colab (similar to Jupyter Notebook) and Python packages that we are going to use throughout the course. The list of core Python packages are
#
# 1. `numpy`: for calculating mathematical functions
# 2. `matplotlib`: for visualization
# 3. `pandas`: for handling data in a table form
# 4. `xarray`: for handling gridded data
# 5. `cartopy`: for visualizing gridded data as a 2D map
# 6. `ipywidgets`: for creating interactive apps(exploration of data)
# 7. `geopandas`: for handling geographic data (e.g., country boundaries)

# %% [markdown]
# ## THE LEARNING GOALS FOR THE WEEK
# (where the course learning goals are in plain text, and the focus this week is in *italics*)
#
#
#
# *   learn about the ways in which climate change and human activity are impacting planet Earth, *with a focus this week in observing – in the data - increases in gases that are driving climate change and negatively impacting air quality; and exploring the link to emissions.*
# *   become familiar with the wide range of sensors available to study various components of the Earth system. These include sensors on satellites, aircraft, ground-based platforms, and deployed above or beneath the surface on land or water. *This week we will work with data acquired using one ground-based measurement station and satellite systems.*
# *   become familiar with the basic physical principles (resolution, sampling, processing workflows, etc.) common to all sensors, *working this week with a range of data sets.*
# *   work with various sources of data, learning how to access, analyze, synthesize, and describe the data to quantify trends; think critically and creatively about how to project these trends into the future. *This week we will work with a number of tools, which will be used again in this course, to transform or analyze the data in various ways and then visualize it.*
# *   describe the complex interactions between human activity and various components of the Earth system. This week a key question: *what is the link between the spatial pattern in emissions and the observed changes in the concentrations of greenhouse and other gases in the atmosphere*.
# *   become motivated to think about new sensors and new ways of using sensor data to study the planet. *This is always the last question in each assignment. Given all that you now know about greenhouse gases, emissions, climate change, what does the planet and all forms of life need you to design and deploy?*

# %% [markdown]
# ## STARTING THE ASSIGNMENT - A WALK THROUGH SOME OF THE DATA AND TOOLS

# %% [markdown]
# ## Install required packages

# %%
# !pip install xarray numpy pandas geopandas cartopy ipywidgets redivis
# Out:
# Requirement already satisfied: xarray in /Users/bchivers/miniconda3/lib/python3.10/site-packages (2023.5.0)
# Requirement already satisfied: numpy in /Users/bchivers/miniconda3/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: pandas in /Users/bchivers/miniconda3/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: geopandas in /Users/bchivers/miniconda3/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: cartopy in /Users/bchivers/miniconda3/lib/python3.10/site-packages (0.24.1)
# Requirement already satisfied: ipywidgets in /Users/bchivers/miniconda3/lib/python3.10/site-packages (8.0.4)
# Requirement already satisfied: redivis in /Users/bchivers/miniconda3/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: packaging>=21.3 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from xarray) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from pandas) (2024.2)
# Collecting shapely>=1.8.0
#   Using cached shapely-2.0.6-cp310-cp310-macosx_11_0_arm64.whl (1.3 MB)
# Requirement already satisfied: fiona>=1.8.21 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: matplotlib>=3.6 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: pyshp>=2.3 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipywidgets) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (4.65.0)
# Requirement already satisfied: pyarrow>=13.0.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (15.0.2)
# Requirement already satisfied: polars>=0.19 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (1.17.1)
# Requirement already satisfied: PyJWT>=2.8.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (2.10.1)
# Requirement already satisfied: folium>=0.15.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (0.19.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (2.28.1)
# Requirement already satisfied: dask>=2023.9.3 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (2024.12.1)
# Requirement already satisfied: mapclassify>=2.6.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from redivis) (2.6.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (2024.10.0)
# Requirement already satisfied: partd>=1.4.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (8.5.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (3.1.0)
# Requirement already satisfied: click>=8.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (8.1.7)
# Requirement already satisfied: toolz>=0.10.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from dask>=2023.9.3->redivis) (6.0.2)
# Requirement already satisfied: cligj>=0.5 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (65.6.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2023.5.7)
# Requirement already satisfied: six in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from folium>=0.15.0->redivis) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from folium>=0.15.0->redivis) (0.6.0)
# Requirement already satisfied: xyzservices in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from folium>=0.15.0->redivis) (2024.9.0)
# Requirement already satisfied: psutil in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.1.0)
# Requirement already satisfied: appnope in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: pyzmq>=17 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: backcall in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from mapclassify>=2.6.0->redivis) (1.3.2)
# Requirement already satisfied: networkx>=2.7 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from mapclassify>=2.6.0->redivis) (3.2)
# Requirement already satisfied: scipy>=1.8 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from mapclassify>=2.6.0->redivis) (1.10.1)
# Requirement already satisfied: cycler>=0.10 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.6->cartopy) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from requests>=2.0.0->redivis) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from requests>=2.0.0->redivis) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from requests>=2.0.0->redivis) (2.0.4)
# Requirement already satisfied: zipp>=3.20 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask>=2023.9.3->redivis) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from jinja2>=2.9->folium>=0.15.0->redivis) (2.1.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: locket in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from partd>=1.4.0->dask>=2023.9.3->redivis) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: joblib>=1.1.1 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify>=2.6.0->redivis) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify>=2.6.0->redivis) (3.2.0)
# Requirement already satisfied: pure-eval in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/bchivers/miniconda3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.2)
# Installing collected packages: shapely
# Successfully installed shapely-2.0.6

# %% [markdown]
# ## Download required data

# %%
import redivis

user = redivis.user("sdss")
dataset = user.dataset("geophysics_115_taking_the_pulse_of_the_planet:fg2x:next")
table = dataset.table("atmosphere_data:9be7")

# Load table as a dataframe
df = table.to_pandas_dataframe(max_results=100)
df.head()

# This table contains file references, to download:
table.download_files('./taking_the_pulse_atmosphere_data/',overwrite=True)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ? files/s]
# 0.00 (?B/s)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Working with CO2 data - one time-series at one location in a table format using `pandas`
#
# Let's start with a monthly time-series of CO2 level measured at Mauna Loa Observatory. We are going to read the CO2 level in a csv format using `pandas`. Loaded table is the pandas' `dataframe`, which allows you to explore the data.

# %%
import pandas as pd

# %%
df_co2 = pd.read_csv('./taking_the_pulse_atmosphere_data/co2_gml.csv')

# %%
df_co2.head(2)
# Out:
#      year  month  monthly_average_co2  de-seasonalized_co2
# 0  1958.0    3.0               315.70               314.43
# 1  1958.0    4.0               317.45               315.16

# %%
df_co2.tail(3)
# Out:
#        year  month  monthly_average_co2  de-seasonalized_co2
# 774  2022.0    9.0               415.95               419.50
# 775  2022.0   10.0               415.78               419.14
# 776  2022.0   11.0               417.51               419.53

# %% [markdown]
# Access data in pandas dataframe.

# %%
import datetime
# generate DatetimeIndex from years and months
years = df_co2['year'].values.astype(int)
months = df_co2['month'].values.astype(int)
times = [datetime.date(years[ii], months[ii], 1) for ii in range(df_co2.shape[0])]
time_series = pd.to_datetime(times)
df_co2['time'] = time_series
df_co2 = df_co2.set_index('time')

# %% [markdown]
# Explain the above cell line-by-line
#
# - numpy array
# - list comprehension
# - `datetime.date`
# - `pd.to_datetime`
# - ...
#
# > **_NOTE:_**  useful keyboard shortcuts:
# - running a cell: `shift + enter`
# - auto completion: `control + space` on windows or `command + space` on mac

# %% [markdown]
# Now we are ready to plot the data in the CO2 time-series. Let's plot them using `pandas`.

# %%
df_co2.plot(y='monthly_average_co2')
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# We could fine-tune the plot using `matplotlib`.

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
df_co2.plot(y='monthly_average_co2', ax=ax)
df_co2.plot(y='de-seasonalized_co2', ax=ax)
ax.grid(True, alpha=0.2)
ax.set_ylabel("CO2 level (ppm)")
ax.legend()

# %% [markdown]
# Suppose you just wanted to plot the data between 1960 and 1980, you could use `numpy`.

# %%
import numpy as np

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
year_min = 2015
year_max = 2022
# find indicies between 1960 and 1980
index_time = np.logical_and(year_min<time_series.year, year_max>=time_series.year)
df_co2.loc[time_series[index_time]].plot(y='monthly_average_co2', ax=ax)
df_co2.loc[time_series[index_time]].plot(y='de-seasonalized_co2', ax=ax)
ax.grid(True, alpha=0.2)
ax.set_ylabel("CO2 level (ppm)")
ax.legend()

# %% [markdown]
# Although the table includes `de-seasonalized_co2`, as an exercise we are going to do this ourselves, starting with the total data and then removing seasonal changes by using a moving average.

# %%
moving_average_window_size = 12
df_series = df_co2['monthly_average_co2'].rolling(window=moving_average_window_size, center=True).mean()

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
year_min = 1960
year_max = 1980
index_time = np.logical_and(year_min<time_series.year, year_max>=time_series.year)
ax.plot(time_series[index_time], df_co2['monthly_average_co2'].values[index_time], label="CO2", marker='None')
ax.plot(time_series[index_time], df_co2['de-seasonalized_co2'].values[index_time], label="CO2 without seasonal changes", marker='None')
df_series.loc[time_series[index_time]].plot(label='C02 moving average')
ax.grid(True, alpha=0.2)
ax.set_ylabel("CO2 level (ppm)")

ax.legend()

# %% [markdown]
# You could also estimate a linear trend using linear regression.

# %%
def linear_fit(time_series, data):
    # assume the time series has a regular sampling rate
    times = np.arange(len(time_series))
    G = np.c_[times, np.ones_like(times)]
    Pinv = np.linalg.pinv(G)
    m = Pinv.dot(data)
    predicted_data = G @ m
    slope = m[0,:]
    intercept = m[1,:]
    return predicted_data, slope, intercept

# %%
predicted_data, slope, intercept = linear_fit(time_series[index_time], df_co2['monthly_average_co2'].values[index_time].reshape([-1,1]))

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
ax.plot(time_series[index_time], df_co2['monthly_average_co2'].values[index_time], label="CO2", marker='None')
ax.plot(time_series[index_time], predicted_data, label="Linear fit", marker='None')
ax.grid(True, alpha=0.2)
ax.set_ylabel("CO2 level (ppm)")
ax.legend()

# %% [markdown]
# Let's add the linear trend back to the dataframe.

# %%
# Estimate the linear trend for all times
predicted_data, _, _ = linear_fit(time_series[:], df_co2['monthly_average_co2'].values[:].reshape([-1,1]))
df_co2['linear_trend_co2'] = predicted_data

# %%
df_co2.head(3)
# Out:
#               year  month  monthly_average_co2  de-seasonalized_co2  \
# time
# 1958-03-01  1958.0    3.0               315.70               314.43
# 1958-04-01  1958.0    4.0               317.45               315.16
# 1958-05-01  1958.0    5.0               317.51               314.71
#
#             linear_trend_co2
# time
# 1958-03-01        305.468965
# 1958-04-01        305.603486
# 1958-05-01        305.738008

# %% [markdown]
# The data are monthly, but sometimes we are interested in looking at annual trends, so summing all the months in each year. We are going to use the `groupby` operation available through the pandas dataframe.

# %%
df_co2_annual = df_co2.groupby('year')['monthly_average_co2'].mean()

# %%
df_co2_annual.head(3)
# Out:
# year
# 1958.0    315.232000
# 1959.0    315.980833
# 1960.0    316.910000
# Name: monthly_average_co2, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
df_co2_annual.plot(legend=False, ax=ax)
ax.grid(True, alpha=0.2)
ax.set_ylabel("CO2 level (ppm)")
# Out:
# Text(0, 0.5, 'CO2 level (ppm)')

# %% [markdown]
# ## Working with gridded CO2 data using `xarray` and `cartopy`
#
# ### Introducing `xarray`
#
# Now, we are going to load the gridded CO2 data in a [NETCDF](https://www.unidata.ucar.edu/software/netcdf/) format - a widely used data format for various atmopheric data.

# %%
import xarray as xr

# %%
co2_data = xr.load_dataset('./taking_the_pulse_atmosphere_data/co2.nc')

# %% [markdown]
# Provide a nice summary of data structure.

# %%
co2_data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 84, lat: 180, lon: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-31 2015-02-28 ... 2021-12-31
#   * lon      (lon) float64 -179.8 -178.8 -177.8 -176.8 ... 177.2 178.2 179.2
#   * lat      (lat) float64 89.75 88.75 87.75 86.75 ... -87.25 -88.25 -89.25
# Data variables:
#     co2      (time, lat, lon) float64 400.6 400.6 400.6 ... 411.5 411.5 411.5
# Attributes:
#     Description:    CO2 data
#     Unit:           ppmv (part per million per volume)
#     Data document:  https://disc.gsfc.nasa.gov/datasets/OCO2_GEOS_L3CO2_MONTH...

# %% [markdown]
# Let's get some information about the data.
#
# - Time range
# - Temporal resolution
# - ...

# %%
co2_data.time.min()
# Out:
# <xarray.DataArray 'time' ()>
# array('2015-01-31T00:00:00.000000000', dtype='datetime64[ns]')

# %%
co2_data.time.max()
# Out:
# <xarray.DataArray 'time' ()>
# array('2021-12-31T00:00:00.000000000', dtype='datetime64[ns]')

# %%
co2_data.lon
# Out:
# <xarray.DataArray 'lon' (lon: 360)>
# array([-179.75, -178.75, -177.75, ...,  177.25,  178.25,  179.25])
# Coordinates:
#   * lon      (lon) float64 -179.8 -178.8 -177.8 -176.8 ... 177.2 178.2 179.2

# %% [markdown]
# How do you access the data?

# %%
# demo - use co2

# %% [markdown]
# Can we plot select a time slice of the data and plot a 2D map using `xarray`?

# %%
i_time = 0
co2_data.co2.isel(time=i_time).plot(add_colorbar=False, cmap='hot_r')

# %% [markdown]
# Or you could also input a date.

# %%
time = '2016-1-10'
co2_data.co2.sel(time=time, method='nearest').plot(add_colorbar=False, cmap='hot_r')

# %% [markdown]
# ### Introducing cartopy
#
# 2D maps are very colorful, but it would be helpful if we could see the continental boundaries.

# %%
import cartopy.crs as ccrs
import cartopy.feature as cf

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.axes.add_feature(cf.COASTLINE)

time = '2016-1-10'
out = co2_data.co2.sel(time=time, method='nearest').plot(add_colorbar=False, cmap='hot_r', ax=ax)
cb = plt.colorbar(out, fraction=0.04, orientation='horizontal')
cb.set_label("Monthly rate (ppmv/month)")
ax.set_aspect(1)

gl = ax.gridlines(
    crs=ccrs.PlateCarree(), 
    draw_labels=True,
    linewidth=1, 
    color='gray', 
    alpha=0.5, 
    linestyle='--'
)

# %% [markdown]
# We could also select multiple times. Let's say we want all data between 2020-01 and 2021-12. Then we could first find corresponding indices of `time_series_co2` then input them to the `co2_data`.

# %%
time_series_co2 = pd.to_datetime(co2_data.time.data)
index_tmp = np.logical_and(time_series_co2.year>=2015, time_series_co2.year<=2019)
co2_data_tmp = co2_data.sel(time=time_series_co2[index_tmp])
co2_data_tmp
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 60, lat: 180, lon: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-31 2015-02-28 ... 2019-12-31
#   * lon      (lon) float64 -179.8 -178.8 -177.8 -176.8 ... 177.2 178.2 179.2
#   * lat      (lat) float64 89.75 88.75 87.75 86.75 ... -87.25 -88.25 -89.25
# Data variables:
#     co2      (time, lat, lon) float64 400.6 400.6 400.6 ... 407.1 407.1 407.1
# Attributes:
#     Description:    CO2 data
#     Unit:           ppmv (part per million per volume)
#     Data document:  https://disc.gsfc.nasa.gov/datasets/OCO2_GEOS_L3CO2_MONTH...

# %% [markdown]
# Access all the CO2 data and plot them in a histogram.

# %%
# comment about the Mauna Loa data. 
out = plt.hist(co2_data.co2.data.flatten(), bins=30, edgecolor='k')
plt.xlabel("CO2 level (ppm)")
# Out:
# Text(0.5, 0, 'CO2 level (ppm)')

# %% [markdown]
# Now let's make an interactive plot.

# %%
from ipywidgets import widgets, interact
def plot_co2(i_time):
    fig = plt.figure(figsize=(20, 10))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.axes.add_feature(cf.COASTLINE)

    time = '2016-1-10'
    out = co2_data.co2.isel(time=i_time).plot(
        add_colorbar=False, cmap='hot_r', ax=ax,
        # fix the color range
        vmin=390, vmax=420
      )
    cb = plt.colorbar(out, fraction=0.04, orientation='horizontal')
    cb.set_label("Monthly rate (ppmv/month)")
    ax.set_aspect(1)
    ax.set_aspect(1)
    plt.show()

# %% [markdown]
# Before you run the cell below, and toggle the time slider through the data, first think about what you expect to see. The best way to catch problems with data or with your analysis is to first THINK about what you expect to see in the data. If what you see is very different from what you expected to see, you might want to check on the data and/or your workflow.

# %%
interact(plot_co2, i_time = widgets.IntSlider(min=0, max=83, step=12))
# Out:
# interactive(children=(IntSlider(value=0, description='i_time', max=83, step=12), Output()), _dom_classes=('wid…
# <function __main__.plot_co2(i_time)>

# %% [markdown]
# We can do many more things using `xarray`. Let's calculate the mean CO2 values along the axes of Latitude and Longitude. Then plot the resulting time-series.

# %%
co2_mean_time_series = co2_data.mean(dim=['lat','lon'])
# below does not work..., unfortunately
# co2_mean_time_series.plot()
plt.plot(co2_mean_time_series.time, co2_mean_time_series.co2.data)

# %% [markdown]
# Or we could calculate the mean along the longitudinal axis (which allows us to see what is usually the greater variation in the latitudinal direction), and plot profiles of CO2 at different times.

# %%
co2_lat = co2_data.mean(dim=['lon'])
# use the same date
out = co2_lat['co2'].isel(time=[0, 2, 4, 6, 8]).plot.line(y='lat', hue='time', add_legend=True)

# %% [markdown]
# Now we are going to calculate the rate of change in the monthly CO2 measurements at every grid point in space. What we display is called a trend map.

# %%
# Get co2 data as a numpy array, then reshape
co2_vec = co2_data.co2.data.reshape((co2_data.co2.data.shape[0], np.prod(co2_data.co2.data.shape[1:])))
time_series_co2 = pd.to_datetime(co2_data.time.data)
co2_linear_fit, slope, intercept = linear_fit(time_series_co2, co2_vec)

# Add resutls back to co2_data
co2_data['slope'] = (("lat", "lon"), slope.reshape(co2_data.co2.data.shape[1:]))
co2_data['intercept'] = (("lat", "lon"), intercept.reshape(co2_data.co2.data.shape[1:]))
co2_data['co2_linear_fit'] = (("time", "lat", "lon"), co2_linear_fit.reshape(co2_data.co2.data.shape))

time_min = pd.to_datetime(time_series_co2).min().strftime('%Y-%m')
time_max = pd.to_datetime(time_series_co2).max().strftime('%Y-%m')

# %% [markdown]
# Then plot the trend map.

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.axes.add_feature(cf.COASTLINE)

out = co2_data['slope'].plot(ax=ax, add_colorbar=False, cmap='hot_r')
cb = plt.colorbar(out, fraction=0.04, orientation='horizontal')
cb.set_label("Monthly rate (ppmv/month)")
ax.set_aspect(1)
gl = ax.gridlines(
    crs=ccrs.PlateCarree(), 
    draw_labels=True,
    linewidth=1, 
    color='gray', 
    alpha=0.5, 
    linestyle='--'
)
ax.set_title("Monthly rate of CO2 level increase between {:s} and {:s}".format(time_min, time_max))
plt.show()

# %% [markdown]
# We could also use other type of geographical data provide boundaries of countries using `geopandas`.

# %% [markdown]
# ## Working with geographic boundaries using `geopandas`
#
# `geopandas`allows us to use other types of geographical data.
# Let's use `geopandas` and read in a `geojson` file.

# %%
import geopandas as gpd
gdf_boundaries = gpd.read_file("./taking_the_pulse_atmosphere_data/world-administrative-boundaries.geojson")

# %%
country_names = np.sort(gdf_boundaries.name.values)
gdf_boundaries = gdf_boundaries.set_index('name')

# %%
# top10_countries

# %% [markdown]
# Use what is provided below in `country_names` to select the top 10 countries you found in terms of emissions.

# %%
widget_country = widgets.Select(options=country_names)
widget_country
# Out:
# Select(options=('Abyei', 'Afghanistan', 'Aksai Chin', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Ango…

# %%
widget_country.value
# Out:
# 'Abyei'

# %% [markdown]
# Alter the name of the countries in the cell below with the top 10 countriees that you have found.

# %%
names = [
    'China', 
    'United States of America', 
    'India', 
    'Russian Federation', 
    'Japan', 
    'Iran (Islamic Republic of)', 
    'Germany',
    'Republic of Korea',
    'Saudi Arabia',
    'Indonesia'
]

# %%
gdf_boundaries_top_10_co2 = gdf_boundaries.loc[names]
fig = plt.figure(figsize=(10, 5))
ax = plt.axes(projection=ccrs.PlateCarree())
gdf_boundaries_top_10_co2.plot(ax=ax, color='r')
gdf_boundaries.boundary.plot(color='k', ax=ax)
# Out:
# <GeoAxes: >

# %% [markdown]
# We could color code the countries with some values. Let's calculate the area of each county then plot it up.

# %%
areas = [geom.area for geom in gdf_boundaries.geometry]

# %%
gdf_boundaries['area'] = areas

# %%
gdf_boundaries.plot(column='area', cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# -----
# ## THE REST OF THE ASSIGNMENT - Homework Questions
#
# ### Q1: Working with the CO2 time-series measured at Mauna Loa Observatory, calculate the mean CO2 values for each month, and plot the resulting values as a function of month; for CO2 values use the second column - "monthly_average_co2". **[Hint: use `groupby` operation]** Write the relevant codes in the below cell. A) What do you see in the plot? Describe the plot. B) Given what you have heard in class what are the possible causes of the seasonality?

# %%
# Fill in this cell with codes to generate the plot

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ### Q2: Working with the same time-series, calculate the trend of CO2 (i.e. rate in ppmv/decade) within each decade starting from 1950 and ending 2020 using the `linear_fit` function. Plot the resulting rates as a function of the starting year of the decade. Write the relevant codes in the cell below. Which decade shows the largest CO2 increase?

# %%
# Fill in this cell with codes to generate the plot

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ### Q3: Working with the gridded CO2 data over the entire time span, produce the trend map. Then in the same plot show the boundaries of the 10 countries you identified as the top for emissions. Write the relevant codes in the cell below. Is there a relationship between the location of the top 10 countries and the location of regions with a high CO2 rate? Explain your observation.

# %%
# Fill in this cell with codes to generate the plot

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ### Q4: Choose a gridded data set from among three given below and produce a trend map, showing the coast lines on the map.
#
# - CH4: ./taking_the_pulse_atmosphere_data/ch4.nc
# - NO2: ./taking_the_pulse_atmosphere_data/no2.nc
# - CO: ./taking_the_pulse_atmosphere_data/co.nc

# %%
# Fill in this cell with codes to generate the plot

# %% [markdown]
# Put your answer here.
